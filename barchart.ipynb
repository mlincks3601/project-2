# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
tour_df = pd.read_csv("tour.csv")
tour_df.head()
# Out:
#    id     city_id         city            state         country  year  \
# 0   1  1840028140       Albany         New York   United States  2019
# 1   2  1840019176  Albuquerque       New Mexico   United States  2010
# 2   3  1840003684  Asbury Park       New Jersey   United States  2015
# 3   4  1840013411    Asheville   North Carolina   United States  2010
# 4   5  1840019407      Atlanta          Georgia   United States  2019
#
#                    band      lat      long
# 0                Pixies  37.8898 -122.3018
# 1         Willie Nelson  35.1053 -106.6464
# 2                Pixies  40.2226  -74.0119
# 3                Pixies  35.5704  -82.5536
# 4  Bring Me the Horizon  33.1136  -94.1672

# %%
new_tour_df = tour_df.set_index("year")
new_tour_df
# Out:
#        id     city_id             city            state         country  \
# year
# 2019    1  1840028140           Albany         New York   United States
# 2010    2  1840019176      Albuquerque       New Mexico   United States
# 2015    3  1840003684      Asbury Park       New Jersey   United States
# 2010    4  1840013411        Asheville   North Carolina   United States
# 2019    5  1840019407          Atlanta          Georgia   United States
# ...   ...         ...              ...              ...             ...
# 2010  340  1840015576       Wilmington         Delaware   United States
# 2005  341  1840002703  Wisconsin Dells        Wisconsin   United States
# 2015  342  1840000434        Worcester    Massachusetts   United States
# 2005  343  1840000434        Worcester    Massachusetts   United States
# 2005  344  1840016201          Zebulon   North Carolina   United States
#
#                       band      lat      long
# year
# ...

# %%
# Split up our data into groups based upon 'band'
grouped_tour_df = new_tour_df.groupby('year')

# Find out how many of each date took bike trips
value_count_df = grouped_tour_df['band'].value_counts()

# Drop the 'stoptime' row that is contained within our group
value_count_df = value_count_df.drop(columns =["id", "city_id", "city", "state", "country", "lat", "long"])

# Chart our data, give it a title, and label the axes
bar_chart_df = value_count_df.plot(kind = "barh", title = "Concerts by Year")
bar_chart_df.set_xlabel("Number of Concerts")
bar_chart_df.set_xticks([0,5,10,15,20,25,30,35,40,45,50,55,60,65,70])
bar_chart_df.set_ylabel("bands")

plt.show()
plt.tight_layout()

# %%
# Find out how many of each date took bike trips
#value_count_df = grouped_tour_df['band'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-4743847c5a7b> in <module>
#       1 # Find out how many of each date took bike trips
#       2 #value_count_df = grouped_tour_df['band'].value_counts()
# ----> 3 tour_df.value_counts()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'
